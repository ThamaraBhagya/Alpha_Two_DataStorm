# %%
# import pandas as pd

# df = pd.read_csv('your_file.csv')

# # Get unique Distributor_ID for each Outlet_ID
# result = df.groupby('Outlet_ID')['Distributor_ID'].unique().reset_index()

# print(result)
